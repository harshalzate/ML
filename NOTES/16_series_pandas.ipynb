# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
Country = ['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(['India','Pakistan','USA','Nepal','Srilanka'])
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]
runs_ser = pd.Series(runs)

# %%
marks=[2,4,5]
peopel=[44,55,33]
pd.Series(marks,index=peopel)        #################### capital S   #####
# Out:
# 44    2
# 55    4
# 33    5
# dtype: int64

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']
pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
Marks=[74,87,43,80,60,90]
Subjects = ['Maths','English','Science','social','gew','gray']
pd.Series(Marks,index=Subjects)
# Out:
# Maths      74
# English    87
# Science    43
# social     80
# gew        60
# gray       90
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Nitish ke marks')          ##################################
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %%
Marks=[74,87,43,80,60,90]
Subjects = ['Maths','English','Science','social','gew','gray']
pd.Series(Marks,index=Subjects,name='Harshal ke marks')
# Out:
# Maths      74
# English    87
# Science    43
# social     80
# gew        60
# gray       90
# Name: Harshal ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='nitish ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'nitish ke marks'

# %%
# is_unique
marks_series.is_unique
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
marks_series.size
# Out:
# 4

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
subs = pd.read_csv('/content/subs.csv',squeeze=True)   ####### squeeze for output as series else dataset gets imported as the dataframe
subs
# Out:
# <ipython-input-19-390e86c95ece>:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   subs = pd.read_csv('/content/subs.csv',squeeze=True)   ####### squeeze for output as series else dataset gets imported as the dataframe
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-390e86c95ece> in <cell line: 2>()
#       1 # with one col
# ----> 2 subs = pd.read_csv('/content/subs.csv',squeeze=True)   ####### squeeze for output as series else dataset gets imported as the dataframe
#       3 subs
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
# ...

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)  ############# index columns has to be defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1f0522373ea> in <cell line: 2>()
#       1 # with 2 cols
# ----> 2 vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)  ############# index columns has to be defined
#
# NameError: name 'pd' is not defined

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
movies

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()

# %%
vk.head(3)

# %%
vk.tail(10)

# %%
# sample
movies.sample(5)

# %%
# value_counts -> movies
movies.value_counts()  #########################################################  returns the series with Frequency of the seris ###############

# %%
# sort_values -> inplace
vk.sort_values(ascending=False).head(1).values[0]

# %%
vk.sort_values(ascending=False)

# %%
# sort_index -> inplace -> movies
movies.sort_index(ascending=False,inplace=True)  ##########################  permanant change #################

# %%
movies

# %%
vk.sort_values(inplace=True)

# %%
vk

# %% [markdown]
# ### Series Maths Methods

# %%
# count
vk.count()

# %%
vk.count()

# %%
vk.sum()
vk.median()
vk.mean()
vk.mode()
vk.median()
vk.std()

# %%
# sum -> product
subs.sum()

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
vk.describe()

# %%
# min/max
subs.max()

# %%
# describe
subs.describe()

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x

# %%
# negative indexing # not supported
x[1]

# %%
movies[0:1]

# %%
vk[-1]

# %%
marks_series[-1]

# %%
# slicing
vk[5:16]

# %%
vk[-4:-1]

# %%
# negative slicing
vk[-5:]

# %%
movies[::2]

# %%
# fancy indexing
vk[[1,3,4,5]]

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']

# %% [markdown]
# ### Editing Series

# %%
Marks_series[1]=50

# %%
# using indexing
marks_series[1] = 100
marks_series

# %%
# what if an index does not exist
marks_series['evs'] = 100                                   ############################### it gets added to the ##########3

# %%
marks_series

# %%
# slicing
runs_ser[2:4] = [100,100]
runs_ser

# %%
runs_ser[[0,2,3]]=[0,1,1]

# %%
runs_ser[[1,4]]

# %%
# fancy indexing
runs_ser[[0,3,4]] = [0,0,0]     ########################################3
runs_ser

# %%
# using index label
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))

# %%
print(dir(subs))

# %%
# type conversion
list(marks_series)

# %%
dict(marks_series)

# %%
movies.sort_values()

# %%
# membership operator
'2 States (2014 film)' in movies                            #########################################################

# %%
'Uri: The Surgical Strike' in movies

# %%
'Alia Bhatt' in movies.values

# %%
'Vicky Kaushal' in movies.values        #######################33 by default it takes index for values we gotta specify values #######

# %%
for i in movies.index:
  print(i)

# %%
# looping
for i in movies.index:
  print(i)

# %%
# Arithmetic Operators(Broadcasting)      ####################
100 + marks_series

# %%
marks_series

# %%
marks_series + 100  ################## broadcasting ###############

# %%
# Relational Operators
vk[vk >= 50]

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size

# %%
vk[(vk>50) | (vk>100)].size

# %%
# find number of ducks
vk[vk == 0].size

# %%
subs[subs>50].size

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size

# %%
num_movies=movies.value_counts()
num_movies[num_movies>20]

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]

# %% [markdown]
# ### Plotting Graphs on Series

# %%
Marks=pd.Series(Marks)
Marks.plot()

# %%
movies.value_counts().head(20).plot(kind='pie')

# %% [markdown]
# ### Some Important Series Methods

# %%
# astypegn
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv('/content/subs.csv',squeeze=True)
subs

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)
vk

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
movies

# %%
# astype
import sys
sys.getsizeof(vk)

# %%
subs.astype('int32')

# %%
#subs[subs.between(50,100)]
h=pd.Series([1,1,5,4,4,3,6,4])
print(h.clip(2,4))
h[h.duplicated()]
h.drop_duplicates(inplace=True)
h
# Out:
# 0    2
# 1    2
# 2    4
# 3    4
# 4    4
# 5    3
# 6    4
# 7    4
# dtype: int64
# 0    1
# 2    5
# 3    4
# 5    3
# 6    6
# dtype: int64

# %%
sys.getsizeof(vk.astype('int16'))

# %%
# between
vk[vk.between(51,99)].size

# %%
# clip
subs

# %%
subs.clip(100,200)

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp

# %%
temp.drop_duplicates(keep='last')

# %%
temp.duplicated().sum()

# %%
vk.duplicated().sum()

# %%
movies.drop_duplicates()

# %%
temp = pd.Series([1,2,3,null,5,6,np.nan,8,np.nan,10])
temp

# %%
temp.size                                   ##########################  counts null as well

# %%
temp.count()                                  #########################  Doesn't counts none #############

# %%
nul=pd.Series([1,2,2,3,4,None,5,None,5,np.nan,np.nan,6])  ########## None and np.nan two ways to represnt null values  both are read as NaN in pandas #############
                                                              ############# None is not represented in numpy though only np.nan is defined in numpy array ###
nul

# %%
nul.dropna(inplace=True)

# %%
bb=np.array([1,2,2,3,4,5,5,np.nan,np.nan,6])#############3 no None defined only np.nan
type(bb)

# %%
bb[np.isnan(bb)]

# %%
pd.isnull(nul).sum()

# %%
nul.isnull().sum()

# %%
# isnull
temp.isnull().sum()

# %%
# dropna
temp.dropna()

# %%
# fillna
temp.fillna(temp.mean())

# %%
# isin
vk[(vk == 49) | (vk == 99)]

# %%
vk[vk.isin([49,99])]####

# %%
# apply
movies

# %%
movies.apply(lambda x:x.split()[0].upper())

# %%
subs

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')

# %%
subs.mean()

# %%
# copy

# %%
vk

# %%
new = vk.head()

# %%
new

# %%
new[1] = 1

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
new

# %%
vk
