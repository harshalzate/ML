# %% [markdown]
# ### **`Problem-1:`** Write a Python function that takes a list and returns a new list with unique elements of the first list.
#
# **Exercise 1:**
#
# Input:
#
# ```bash
# [1,2,3,3,3,3,4,5]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5]
# ```

# %%
x=[1,2,3,3,3,3,4,5]
def unique_list(x):
  return list(set(x))
unique_list(x)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **`Problem-2:`** Write a Python function that accepts a hyphen-separated sequence of words as parameter and returns the words in a hyphen-separated sequence after sorting them alphabetically.
#
# **Example 1:**
#
# Input:
# ```bash
# green-red-yellow-black-white
# ```
#
# Output:
# ```bash
# black-green-red-white-yellow
# ```

# %%
x='green-red-yellow-black-white'
'-'.join(sorted(x.split('-')))
# Out:
# 'black-green-red-white-yellow'

# %% [markdown]
# ### **`Problem 3:`** Write a Python function that accepts a string and calculate the number of upper case letters and lower case letters.
#
# ```
# Sample String : 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
# Expected Output :
# No. of Upper case characters :  9
# No. of Lower case Characters :  47
# ```

# %%
Sample_String = 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
u=0
l=0
Sample_String=Sample_String[:-1]
for i in Sample_String.split():
  for j in i:
    if j==j.upper():
      u=u+1
    elif j==j.lower():
      l=l+1
print(u,l)
# Out:
# 9 47

# %% [markdown]
# ### **`Problem 4:`** Write a Python program to print the even numbers from a given list.
# ```
# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Expected Result : [2, 4, 6, 8]
# ```

# %%
Sample_List = [1, 2, 3, 4, 5, 6, 7, 8, 9]
l=[]
for i in Sample_List:
  if i%2==0:
    l.append(i)
print(l)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ### **`Problem 5:`** Write a Python function to check whether a number is perfect or not.
#
# A Perfect number is a number that is half the sum of all of its positive divisors (including itself).
#
# Example :
#
# ```
# The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
#
# The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.
# ```

# %%
l=[]
for i in range(2,10000):
  ll=[]
  for j in range(1,i//2+1):
    if i%j==0:
      ll.append(j)
  if sum(ll)==i:
    l.append(i)
l
# Out:
# [6, 28, 496, 8128]

# %% [markdown]
# ### **`Problem-6:`** Write a Python function to concatenate any no of dictionaries to create a new one.
#
# ```
# Sample Dictionary :
# dic1={1:10, 2:20}
# dic2={3:30, 4:40}
# dic3={5:50,6:60}
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# ```

# %%
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}
dic1.update(dic2)     ### update
dic1.update(dic3)
dic1
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# `Problem-7` Write a python function that accepts a string as input and returns the word with most occurence.
#
# ```
# Input:
# hello how are you i am fine thank you
# ```
#
# ```
# Output
# you -> 2
# ```

# %%
h="hello how are you i am fine thank you"
d={}
for i in h.split(' '):
  d[i]=(h.count(i))
(list(sorted(d.items(),key=lambda x:x[1],reverse=True)[0]))
# Out:
# ['you', 2]

# %% [markdown]
# `Problem-8` Write a python function that receives a list of integers and prints out a histogram of bin size 10
#
# ```
# Input:
# [13,42,15,37,22,39,41,50]
# ```
#
# ```
# Output:
# {11-20:2,21-30:1,31-40:2,41-50:3}
# ```

# %%
st=[13,42,15,37,22,39,41,50]
d={}
c1=0
c2=0
c3=0
c4=0
for i in st:
  if i>11 and i<=20:
    c1=c1+1
  elif i>20 and i<31:
    c2=c2+1
  elif i>30 and i<41:
    c3=c3+1
  elif i>40 and i<51:
    c4=c4+1
d['11-20']=c1
d['21-30']=c2
d['31-40']=c3
d['41-50']=c4

# %%
d
# Out:
# {'11-20': 2, '21-30': 1, '31-40': 2, '41-50': 3}

# %% [markdown]
# `Problem-9` Write a python function that accepts a list of 2D co-ordinates and a query point, and then finds the the co-ordinate which is closest in terms of distance from the query point.
#
# ```
# List of Coordinates
# [(1,1),(2,2),(3,3),(4,4)]
# Query Point
# (0,0)
# ```
#
# ```
# Output
# Nearest to (0,0) is (1,1)
# ```

# %%
co = [(1,1),(2,2),(3,3),(4,4)]
q=(0,0)
dicc={}
for i in co:
  d=((q[0]-i[0])**2 + (q[1]-i[1])**2)**(0.5)
  dicc[i]=d
min(dicc)   # this gives min key only
# Out:
# (1, 1)

# %%
min(dicc,key=lambda x:dicc[x])  ## use key for everything sorting and fitering in dictionary (min,sorted,max)
# Out:
# (1, 1)

# %% [markdown]
# `Problem-10`:Write a python program that receives a list of strings and performs bag of word operation on those strings
#
# https://en.wikipedia.org/wiki/Bag-of-words_model

# %%
from collections import Counter
Counter(['harshal','harshal','nayan','ramesh','zate','ramesh','zate'])
# Out:
# Counter({'harshal': 2, 'nayan': 1, 'ramesh': 2, 'zate': 2})

# %%
from collections import Counter
s=input('').split()
c=Counter(s)
c.items()  # dic_items
for i,j in c.items():
  print(i,j)
# Out:
# Harshal is the Harshal
# Harshal 2
# is 1
# the 1

# %% [markdown]
# ###`Problem 11:` Write a Python program to add three given lists using Python map and lambda.

# %%
l1=[1,2,3,4]
l2=[7,8,9,4]
l3=[1,5,8,5]
list(map(lambda x,y,z:x+y+z,l1,l2,l3))
# Out:
# [9, 15, 20, 13]

# %% [markdown]
# ###`Problem-12:`Write a Python program to create a list containing the power of said number in bases raised to the corresponding number in the index using Python map.
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,2,9,64,625,-]
# ```

# %%
listt=[1,2,3,4,5,6]
new_list =[]
for i,j in enumerate(listt):
  new_list.append(j**i)
new_list
# Out:
# [1, 2, 9, 64, 625, 7776]

# %% [markdown]
# ###`Problem-13` Using filter() and list() functions and .lower() method filter all the vowels in a given string.

# %%
string='Hello, World'
list(filter(lambda x:x.islower() and x in ['a','e','i','o','u'],string))
# Out:
# ['e', 'o', 'o']

# %% [markdown]
# `Problem-14`: Use reduce to convert a 2D list to 1D

# %%
from functools import reduce
l=[7,2,3,4]
(reduce(lambda x,y:x+y,l))
reduce(lambda x,y:x if x>y else y,l)
# Out:
# 7

# %%
l=[[1,2,3,4],[5,6,7,8]]
reduce(lambda x,y:x+y,l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# `Problem 15`- A dictionary contains following information about 5 employees:
# - First name
# - Last name
# - Age
# - Grade(Skilled,Semi-skilled,Highly skilled)<br>
# Write a program using map/filter/reduce to a list of employees(first name + last name) who are highly skilled

# %%
for i in e:
  if i['grade']=='highly-skilled':
    print(i['fname'],i['lname'])
# Out:
# Neha Singh
# Abhinav Sharma

# %%
list(map(lambda x:x['fname']+' '+ x['lname'],list(filter(lambda x:x['grade']=='highly-skilled',e))))
# Out:
# ['Neha Singh', 'Abhinav Sharma']

# %%
list(filter(lambda x: x ,list(map(lambda x:x['fname'] + " " +x['lname'] if x['grade']=='highly-skilled' else None,e))))
# Out:
# ['Neha Singh', 'Abhinav Sharma']

# %%
# Write code here
e = [
    {
        'fname':'Nitish',
        'lname':'Singh',
        'age' : 33,
        'grade':'skilled'
    },
    {
        'fname':'Ankit',
        'lname':'Verma',
        'age' : 34,
        'grade':'semi-skilled'
    },
    {
        'fname':'Neha',
        'lname':'Singh',
        'age' : 35,
        'grade':'highly-skilled'
    },
    {
        'fname':'Anurag',
        'lname':'Kumar',
        'age' : 30,
        'grade':'skilled'
    },
    {
        'fname':'Abhinav',
        'lname':'Sharma',
        'age' : 37,
        'grade':'highly-skilled'
    }

]

# %%
list(map(lambda x:x['fname'] + x['lname'],(filter(lambda x:x if x['grade']=='highly-skilled' else None,e))))
# Out:
# ['NehaSingh', 'AbhinavSharma']

# %%
list(filter(lambda x:True if x['grade'] == 'highly-skilled' else False,e))
# Out:
# [{'fname': 'Neha', 'lname': 'Singh', 'age': 35, 'grade': 'highly-skilled'},
#  {'fname': 'Abhinav', 'lname': 'Sharma', 'age': 37, 'grade': 'highly-skilled'}]

# %%
list(map(lambda x:x['fname'] + ' ' + x['lname'],list(filter(lambda x:True if x['grade'] == 'highly-skilled' else False,e))))
# Out:
# ['Neha Singh', 'Abhinav Sharma']
