# %%
n_i=['Age','Pclass','Fare','c','Survived']
df.reindex(columns=n_i)

# %%
df['category'].astype('o') # check for object datatype

# %%
df = df.iloc[:,0:-1]
df.iloc[1,0] = np.NaN  # will throw error
pd.options.mode.copy_on_write = True  # this solve the problem

# %%
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# either use (-1,1) dynamic array shape or use [['feature_name']]

# %%
# carefule with ohe transformer as it return multiple columsn so we have to store them differently while assigning them back to the dataframe
