# %%
# Shift most important learning to the Basics

# %%
# vebose parameter in any ML class it used to specify the level of info display while execution
# where value verbose=0 means no info and subsequently value = 1 means progress bar and verbose=2 means detail info is displyed

# %%
# n_jobs=-1
# allows all the cores in parallel computation

# %%
 # plt.plot(samples,bins=10,density=True) # Density = True means the normalized plot area under is 1

# %%
# reshape
import numpy as np
a=np.array([1,2,3,4,5,6])
# I need 2 rows it automatically calculates the columns based on the element just specify -1 as column
a.reshape(2,-1)

# %%
# np.log and np.log1p
 # difference is log1p is natural log having (1+x)

# %%
# Continous and discrete distributions
# Binomial bernolli geometric hypergeometric poission negatice bernolli and uniform are discrete distribution
# and
# Gaussian/Noraml uniform, exponential, gamma,betta,student t distribution, log distribution, chi-squared distribution, f distribution
