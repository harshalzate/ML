# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Timestamp Object
#
# Time stamps reference particular moments in time (e.g., Oct 24th, 2022 at 7:00pm)

# %% [markdown]
# ### Creating Timestamp objects

# %%
# creating a timestamp  ################ Pandas ############ DateTime = Python
type(pd.Timestamp('2023/1/5'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pd.datetime(2020,3,4,5,8,9)
pd.Timestamp('2023-01-22 9:30 PM')
pd.Timestamp('2024-01-22 8:45AM')
pd.Timestamp(pd.datetime(2020,3,4))
# Out:
# <ipython-input-5-3bde7c7b64af>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime(2020,3,4,5,8,9)
# <ipython-input-5-3bde7c7b64af>:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.Timestamp(pd.datetime(2020,3,4))
# Timestamp('2020-03-04 00:00:00')

# %%
# variations
a=pd.Timestamp('2023-1-5')
b=pd.Timestamp('2023, 1, 5')

# %%
# only year
pd.Timestamp('2023')
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
# using text
pd.Timestamp('5th January 2023')
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
# providing time also
pd.Timestamp('5th January 2023 9:21AM')
# pd.Timestamp('2023/1/5/9/21')
# Out:
# Timestamp('2023-01-05 09:21:00')

# %%
pd.Timestamp('2020/1/2 9:20 PM')                      ###############################
# Out:
# Timestamp('2020-01-02 21:20:00')

# %%
# AM and PM

# %%
# using datetime.datetime object
import datetime as dt

x = pd.Timestamp(dt.datetime(2023,1,5,9,21,56))
type(x)
x
# Out:
# Timestamp('2023-01-05 09:21:56')

# %%
# fetching attributes                                          ################# Can fetch like this but not in dataframes where you have to use dt and differet fucntion
x.year
x.month
x.day
x.hour
x.minute
x.second
# Out:
# 56

# %%
# why separate objects to handle data and time when python already has datetime functionality?

# %% [markdown]
# syntax wise datetime is very convenient
# - But the performance takes a hit while working with huge data. List vs Numpy Array
# - The weaknesses of Python's datetime format inspired the NumPy team to add a set of native time series data type to NumPy.
# - The datetime64 dtype encodes dates as 64-bit integers, and thus allows arrays of dates to be represented very compactly.

# %%
import numpy as np
date = np.array('2015-07-04', dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
print(date + np.arange(12))
type(date + np.arange(12))     ######################### Vector Operations are Possible ############################
# Out:
# ['2015-07-04' '2015-07-05' '2015-07-06' '2015-07-07' '2015-07-08'
#  '2015-07-09' '2015-07-10' '2015-07-11' '2015-07-12' '2015-07-13'
#  '2015-07-14' '2015-07-15']
# numpy.ndarray

# %% [markdown]
# - Because of the uniform type in NumPy datetime64 arrays, this type of operation can be accomplished much more quickly than if we were working directly with Python's datetime objects, especially as arrays get large
#
# - Pandas Timestamp object combines the ease-of-use of python datetime with the efficient storage and vectorized interface of numpy.datetime64
#
# - From a group of these Timestamp objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame

# %% [markdown]
# ### DatetimeIndex Object
#
# A collection of pandas timestamp

# %%
# from strings
type(pd.DatetimeIndex(['2023/1/1','2022/1/1','2021/1/1']))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# using python datetime object
pd.DatetimeIndex([dt.datetime(2023,1,1),dt.datetime(2022,1,1),dt.datetime(2021,1,1)])
# Out:
# DatetimeIndex(['2023-01-01', '2022-01-01', '2021-01-01'], dtype='datetime64[ns]', freq=None)

# %%
# using pd.timestamps
dt_index = pd.DatetimeIndex([pd.Timestamp(2023,1,1),pd.Timestamp(2022,1,1),pd.Timestamp(2021,1,1)])

# %%
# using datatimeindex as series index
pd.Series([1,2,3],index=dt_index)
# Out:
# 2023-01-01    1
# 2022-01-01    2
# 2021-01-01    3
# dtype: int64

# %%
p.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2d09ef090cc0> in <cell line: 1>()
# ----> 1 p.year
#
# NameError: name 'p' is not defined

# %%
p=pd.DatetimeIndex(['2022-1-1','2023-2-2','2024-5-4'])
pd.Series([1,2,3],index=p)
# Out:
# 2022-01-01    1
# 2023-02-02    2
# 2024-05-04    3
# dtype: int64

# %%
pd.DatetimeIndex(['2020-02-20','2020-02-20','2020-02-20','2020-02-20'])
# Out:
# DatetimeIndex(['2020-02-20', '2020-02-20', '2020-02-20', '2020-02-20'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### date_range function

# %%
# generate daily dates in a given range
pd.date_range(start='2023/1/5',end='2023/2/28',freq='3D')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-08', '2023-01-11', '2023-01-14',
#                '2023-01-17', '2023-01-20', '2023-01-23', '2023-01-26',
#                '2023-01-29', '2023-02-01', '2023-02-04', '2023-02-07',
#                '2023-02-10', '2023-02-13', '2023-02-16', '2023-02-19',
#                '2023-02-22', '2023-02-25', '2023-02-28'],
#               dtype='datetime64[ns]', freq='3D')

# %%
# alternate days in a given range
pd.date_range(start='2023/1/5',end='2023/2/28',freq='3D')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-08', '2023-01-11', '2023-01-14',
#                '2023-01-17', '2023-01-20', '2023-01-23', '2023-01-26',
#                '2023-01-29', '2023-02-01', '2023-02-04', '2023-02-07',
#                '2023-02-10', '2023-02-13', '2023-02-16', '2023-02-19',
#                '2023-02-22', '2023-02-25', '2023-02-28'],
#               dtype='datetime64[ns]', freq='3D')

# %%
pd.date_range(start='2023/1/5',end='2025/05/23',freq='B')
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-16',
#                '2023-01-17', '2023-01-18',
#                ...
#                '2025-05-12', '2025-05-13', '2025-05-14', '2025-05-15',
#                '2025-05-16', '2025-05-19', '2025-05-20', '2025-05-21',
#                '2025-05-22', '2025-05-23'],
#               dtype='datetime64[ns]', length=622, freq='B')

# %%
# B -> business days
pd.date_range(start='2023/1/5',end='2023/2/28',freq='B')      ########### NO sat sun  ###############
# Out:
# DatetimeIndex(['2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-23', '2023-01-24', '2023-01-25', '2023-01-26',
#                '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-20', '2023-02-21', '2023-02-22', '2023-02-23',
#                '2023-02-24', '2023-02-27', '2023-02-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
# W -> one week per day
pd.date_range(start='2023/1/5',end='2023/2/28',freq='W-Mon')
# Out:
# DatetimeIndex(['2023-01-09', '2023-01-16', '2023-01-23', '2023-01-30',
#                '2023-02-06', '2023-02-13', '2023-02-20', '2023-02-27'],
#               dtype='datetime64[ns]', freq='W-MON')

# %%
# H -> Hourly data(factor)
pd.date_range(start='2023/1/5',end='2023/2/28',freq='6H')
# Out:
# DatetimeIndex(['2023-01-05 00:00:00', '2023-01-05 06:00:00',
#                '2023-01-05 12:00:00', '2023-01-05 18:00:00',
#                '2023-01-06 00:00:00', '2023-01-06 06:00:00',
#                '2023-01-06 12:00:00', '2023-01-06 18:00:00',
#                '2023-01-07 00:00:00', '2023-01-07 06:00:00',
#                ...
#                '2023-02-25 18:00:00', '2023-02-26 00:00:00',
#                '2023-02-26 06:00:00', '2023-02-26 12:00:00',
#                '2023-02-26 18:00:00', '2023-02-27 00:00:00',
#                '2023-02-27 06:00:00', '2023-02-27 12:00:00',
#                '2023-02-27 18:00:00', '2023-02-28 00:00:00'],
#               dtype='datetime64[ns]', length=217, freq='6H')

# %%
# M -> Month end
pd.date_range(start='2023/1/5',end='2023/2/28',freq='M')
# Out:
# DatetimeIndex(['2023-01-31', '2023-02-28'], dtype='datetime64[ns]', freq='M')

# %%
# MS -> Month start
pd.date_range(start='2023/1/5',end='2023/2/28',freq='MS')

# %%
# A -> Year end
pd.date_range(start='2023/1/5',end='2030/2/28',freq='A')      #################################

# %%
# using periods(number of results)
pd.date_range(start='2023/1/5',periods=25,freq='M')

# %%
pd.DatetimeIndex(s)

# %% [markdown]
# ### to_datetime function
#
# converts an existing objects to pandas timestamp/datetimeindex object

# %%
s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
tt=pd.DatetimeIndex(s)
tt.day_name()
# Out:
# Index(['Sunday', 'Saturday', 'Friday'], dtype='object')

# %%
s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
t=pd.to_datetime(s)
t.dt.day_name()
# Out:
# 0      Sunday
# 1    Saturday
# 2      Friday
# dtype: object

# %%
# simple series example
s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
print(type(pd.DatetimeIndex(s)))
pd.to_datetime(s).dt.day_name()
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# 0      Sunday
# 1    Saturday
# 2      Friday
# dtype: object

# %%
# with errors
s = pd.Series(['2023/1/1','2022/1/1','2021/130/1'])
pd.to_datetime(s,errors='coerce').dt.month_name()   #################errors to NaT (Not a Time)
# Out:
# 0    January
# 1    January
# 2        NaN
# dtype: object

# %%
df = pd.read_csv('/content/expense_data (1).csv')
df.shape

# %%
type(df['Date'].values[0])

# %%
df.info()  ############ object means String ###################
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-ddf8fbdb6254> in <cell line: 1>()
# ----> 1 df.info()  ############ object means String ###################
#
# NameError: name 'df' is not defined

# %%
df.head()

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()

# %% [markdown]
# ### dt accessor
#
# Accessor object for datetimelike properties of the Series values.

# %%
df['Date'].dt.day                                 ################## all these fucntion has to be used with dt in there ####################

# %%
df['Date'].dt.is_quarter_start

# %%
# plot graph
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['INR'])

# %%
# day name wise bar chart/month wise bar chart

df['day_name'] = df['Date'].dt.day_name()

# %%
df.head()

# %%
df.groupby('day_name')['INR'].mean().plot(kind='bar')

# %%
df['month_name'] = df['Date'].dt.month_name()

# %%
df.head()

# %%
df.groupby('month_name')['INR'].sum().plot(kind='bar')

# %%
s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
t=pd.to_datetime(s,errors='coerce')
type(t)
t.dt.day_name()

# %%
df[df['Date'].dt.is_month_end]
