# %%
#1
n=5
for i in range(n):
  for i in range(5):
    print('*',end='')
  print('')

# %%
#2
n=5
for i in range(n):
  for k in range(i,n):
    print(' ',end='')
  for j in range(i+1):
    print('*',end='')
  print('')

# %%
#3
n=5
for i in range(n):
  for j in range(i+1):
    print(' ',end='')
  for k in range(i,n):
    print('*',end='')
  print('')

# %%
#4
n=5
for i in range(n):
  for j in range(i,n):
    print(' ',end='')
  for k in range(i+1):
    print('*',end='')
  for l in range(i):
    print('*',end='')
  for m in range(i,n-1):
    print(' ',end='')
  print('')

# %%
#5
n=5
for i in range(n):
  for j in range(i,n):
    print(' ',end='')
  for j in range(i):
    print('*',end=' ')
  print('')

# %%
#6
n=5
for i in range(n):
  for j in range(i):
    print(' ',end='')
  for k in range(i,n):
    print('*',end='')
  for l in range(i,n-1):
    print('*',end='')
  for m in range(i):
    print(' ',end='')
  print('')

# %%
#7
n=9
for i in range(9//2+1):
  for j in range(i,9//2):
    print(' ',end='')
  for k in range(i+1):
    print('*',end='')
  for l in range(i):
    print('*',end='')
  print('')

for i in range(9//2):
  for j in range(i+1):
    print(' ',end='')
  for k in range(i,9//2):
    print('*',end='')
  for l in range(i,9//2-1):
    print('*',end='')
  print('')

# %% [markdown]
# #8
# 11111
#
# 0000
#
# 111
#
# 00
#
# 1

# %%
n=5
for i in range(n):
  if i%2==0:
    for j in range(i,n):
      print(1,end='')
    print('')
  else:
    for k in range(i,n):
      print(0,end='')
    print()

# %% [markdown]
#   # 9
#
#         A
#        ABC
#       ABCDE
#      ABCDEFG
#     ABCDEFGHI

# %%
import string
letters=string.ascii_uppercase

# %%
n=6
for i in range(n):
  for j in range(i,n-1):
    print(' ',end='')
  for k in range(i+1):
    print(chr(k+65),end='')
  for l in range(i):
    print(chr(l+k+1+65),end='')
  print()

# %% [markdown]
# # 10.
#         1
#        123
#       12345
#      1234567
#     123456789
#      1234567
#       12345
#        123
#         1

# %%
n=9
for i in range(n//2+1):
  for j in range(i,n//2):
    print(' ',end='')
  for k in range(i+1):
    print(k+1,end='')
  for l in range(i):
    print(l+k+2,end='')
  print()
for i in range(n//2):
  for j in range(i+1):
    print(' ',end='')
  for k in range(1,n//2-i+1):
    print(k,end='')
  for l in range(i,n//2-1):
    print(l+k+1,end='')
  print()

# %% [markdown]
# #11.
# E
#
# DE
#
# CDE
#
# BCDE
#
# ABCDE

# %%
chr(97)

# %%
chr(65)

# %%
c='E'
ord('E')-5

# %%
for i in range(5,0,-1):
  for j in range(i,6):
    print(chr(64+j),end='')
  print()

# %% [markdown]
# # 12.
# 1
#
# 11
#
# 202
#
# 3003

# %%
n=4
if n==1:
  print(n)
else:
  print(1)
  for i in range(2,n+1):
    print(i-1,end='')
    for j in range(i-2):
      print(0,end='')
    print(i-1,end='')
    print()

# %% [markdown]
# # 13.
# ABCD
#
# ABCD
#
# ABCD
#
# ABCD

# %%
n=4
for i in range(n):
  for j in range(n):
    print(chr(65+j),end='')
  print()

# %% [markdown]
#         *
#        **
#       ***
#      ****
#     *****

# %%
n=5
for i in range(n):
  for k in range(i+1,n):
    print(' ',end='')

  for j in range(i+1):
    print('*',end='')
  print()

# %% [markdown]
# # 14.
#
#
#       ABC
#      ABCDE
#     ABCDEFG
#    ABCDEFGHI

# %%
n=4
for i in range(1,n+1):
  for k in range(i,n):
    print(' ',end='')
  for j in range(2*i+1):
    print(chr(65+j),end='')
  print()
